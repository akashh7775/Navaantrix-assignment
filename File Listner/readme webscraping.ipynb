# %%
# Web Scraping for Product Details (Amazon & Flipkart)

This Python project was built to scrape product details like name, price, and ratings from two e-commerce websites — Amazon and Flipkart — based on user search input. The goal was to collect this data and export it into an Excel file with separate sheets for each site.

## What the Project Does

- Takes a dynamic search term from the user (e.g., "mobile", "headphones")
- Scrapes product details from Amazon and Flipkart
- Extracts the product name, price, and rating
- Saves the results in an Excel file (`product_results.xlsx`) with two sheets:
  - `Amazon`
  - `Flipkart`

## Technologies Used

- Python 3
- `requests` – for sending web requests
- `BeautifulSoup` – for HTML parsing
- `pandas` – for storing and exporting data
- `openpyxl` – to write Excel files

## Known Challenges Faced

While working on this project, I faced some real-world web scraping challenges:

- **Flipkart and Amazon use advanced anti-bot mechanisms** (like dynamic JavaScript content, IP blocks, and bot detection headers).
- Because of this, scraping sometimes **returns empty pages or missing product blocks**.
- This is why, during testing, **the output may show only headers (no product rows)** in the Excel file.
- As a workaround, I also prepared a version of the project that uses **dummy product data** when actual scraping fails. This helped ensure the Excel export logic could still be demonstrated correctly for submission.

## How to Use It

1. Install the required libraries:
pip install requests beautifulsoup4 pandas openpyxl

markdown
Copy
Edit

2. Run the notebook and enter a product name when prompted.

3. The script will attempt to scrape data from both Amazon and Flipkart.

4. Results are saved in `product_results.xlsx` in the same folder.

## Sample Data Structure

Each product entry will ideally look like:

| Product Name       | Price    | Rating  |
|--------------------|----------|---------|
| Samsung Galaxy A15 | ₹12,499  | 4.2     |

## Project Files

- `Updated_Web_Scraping_Project.ipynb`
- `product_results.xlsx`
- `README.md`

## Notes

- Due to site restrictions, some scraping attempts may fail. That’s expected behavior.
- This project was created as part of an interview assignment to demonstrate web scraping, data handling, and file export.
